# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("Data/Fake.csv")
df2 = pd.read_csv("Data/True.csv")

# %%
df1.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df2.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df1["target"] = 1
df2["target"] = 0

# %%
df1.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  target
# 0  December 31, 2017       1
# 1  December 31, 2017       1
# 2  December 30, 2017       1
# 3  December 29, 2017       1
# 4  December 25, 2017       1

# %%
df2.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  target
# 0  December 31, 2017        0
# 1  December 29, 2017        0
# 2  December 31, 2017        0
# 3  December 30, 2017        0
# 4  December 29, 2017        0

# %%
df = pd.concat([df1,df2],ignore_index=True)

# %%
df.sample(5)
# Out:
#                                                    title  \
# 13798  CAUGHT ON CAMERA! ANTI-TRUMP THUGS Stoop To Ne...
# 24778         Trump's not-so-quick fix to undo Obamacare
# 19088  THIS IS OKAY? Loudmouth Entertainer Who Got Mi...
# 13556  WHOA! DNC Releases Statement Suggesting Dallas...
# 34867  Mexican police arrest suspect in crime journal...
#
#                                                     text       subject  \
# 13798  The anti-Trump protesters stoop to a new low a...      politics
# 24778  NEW YORK (Reuters) - President Donald Trump on...  politicsNews
# 19088  Nothing is off-limits for Leslie Jones  stand-...     left-news
# 13556  Of course tomorrow morning, the Democrat Party...      politics
# 34867  MEXICO CITY (Reuters) - A man alleged to be be...     worldnews
#
#                      date  target
# 13798        May 29, 2016       1
# 24778   October 12, 2017        0
# 19088        Feb 25, 2017       1
# 13556         Jul 8, 2016       1
# ...

# %%
final = df.sample(frac=1)

# %%
final.head(10)
# Out:
#                                                    title  \
# 21167  GERMAN RESIDENTS FIGHT BACK: Anti-Islamic Song...
# 15449  (VIDEO) BRAVO! TV HOST SCORCHES OBAMA FOR HIS ...
# 36358  Greek president tells Turkey's Erdogan no trea...
# 2402    Colbert Scorches Trump’s Anti-Trans Bigotry; ...
# 28380  Pentagon chief, Saudi deputy crown prince disc...
# 7608    Meet The ‘Responsible Gun Owner’ Who Was Shot...
# 22879  What’s the Leading Killer of American Adults U...
# 42165  More than 60 Rohingya feared drowned as U.S. s...
# 27303       Trump will not visit FBI headquarters: MSNBC
# 4500    Louisiana Cop Claims Murdering A 6-Year Old C...
#
#                                                     text       subject  \
# 21167  Apparently these Germans are not interested in...     left-news
# 15449                                      I VE HAD IT!       politics
# 36358  ATHENS (Reuters) - Greek President Prokopis Pa...     worldnews
# ...

# %%
final.shape
# Out:
# (44898, 5)

# %%
final["subject"].unique()
# Out:
# array(['left-news', 'politics', 'worldnews', 'News', 'politicsNews',
#        'Middle-east', 'Government News', 'US_News'], dtype=object)

# %%
final.to_csv("Data/fake_real_news.csv", index=False)

# %%
f_r = pd.read_csv("Data/fake_real_news.csv")

# %%
f_r.head()
# Out:
#                                                title  \
# 0  GERMAN RESIDENTS FIGHT BACK: Anti-Islamic Song...
# 1  (VIDEO) BRAVO! TV HOST SCORCHES OBAMA FOR HIS ...
# 2  Greek president tells Turkey's Erdogan no trea...
# 3   Colbert Scorches Trump’s Anti-Trans Bigotry; ...
# 4  Pentagon chief, Saudi deputy crown prince disc...
#
#                                                 text       subject  \
# 0  Apparently these Germans are not interested in...     left-news
# 1                                      I VE HAD IT!       politics
# 2  ATHENS (Reuters) - Greek President Prokopis Pa...     worldnews
# 3  During his campaign, Donald Trump promised tha...          News
# 4  WASHINGTON (Reuters) - U.S. Defense Secretary ...  politicsNews
#
#                 date  target
# 0        Jan 3, 2016       1
# 1       Jul 20, 2015       1
# 2  December 7, 2017        0
# 3  February 24, 2017       1
# 4    March 16, 2017        0

# %%
df_dumies = pd.get_dummies(final, columns=["subject"])

# %%
df_dumies.head()
# Out:
#                                                    title  \
# 21167  GERMAN RESIDENTS FIGHT BACK: Anti-Islamic Song...
# 15449  (VIDEO) BRAVO! TV HOST SCORCHES OBAMA FOR HIS ...
# 36358  Greek president tells Turkey's Erdogan no trea...
# 2402    Colbert Scorches Trump’s Anti-Trans Bigotry; ...
# 28380  Pentagon chief, Saudi deputy crown prince disc...
#
#                                                     text               date  \
# 21167  Apparently these Germans are not interested in...        Jan 3, 2016
# 15449                                      I VE HAD IT!        Jul 20, 2015
# 36358  ATHENS (Reuters) - Greek President Prokopis Pa...  December 7, 2017
# 2402   During his campaign, Donald Trump promised tha...  February 24, 2017
# 28380  WASHINGTON (Reuters) - U.S. Defense Secretary ...    March 16, 2017
#
#        target  subject_Government News  subject_Middle-east  subject_News  \
# 21167       1                    False                False         False
# ...
